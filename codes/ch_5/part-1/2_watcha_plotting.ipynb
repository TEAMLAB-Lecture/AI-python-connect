# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_data = np.array([8759, 10132,12078,16430])
y_data = np.array([487, 612,866,1030])

plt.scatter(x_data,y_data, color = 'r', marker="s")
plt.show()

# %%
weight_0 = np.random.sample(5)
weight_1 = np.random.sample(5)

weight_0, weight_1
# Out:
# (array([ 0.71091668,  0.17970552,  0.32891534,  0.65141852,  0.01430625]),
#  array([ 0.46308286,  0.19514215,  0.58351856,  0.32477459,  0.83310882]))

# %%
y_hat_list = []
for w0, w1 in zip(weight_0,weight_1):
    y_hat_list.append(w0 + w1*x_data)
y_hat_list
# Out:
# [array([ 4056.85368405,  4692.6664503 ,  5593.82569511,  7609.16230016]),
#  array([ 1709.42975372,  1977.35991883,  2357.10653303,  3206.36514814]),
#  array([ 5111.36797357,  5912.53895506,  7048.06607087,  9587.53883961]),
#  array([ 2845.3520388 ,  3291.26754874,  3923.27889788,  5336.69790683]),
#  array([  7297.21447666,   8441.07288903,  10062.30265631,  13687.99224891])]

# %%
plt.scatter(x_data,y_data, color = 'r', marker="s")
for y_hat in y_hat_list:
    plt.plot(x_data, y_hat)

plt.show()

# %%
y_hat[0] - y_data
# Out:
# array([ 7684.19598061,  7559.19598061,  7305.19598061,  7141.19598061])

# %%
sum ( (y_hat - y_data) ** 2 )
# Out:
# 449777581.04137391
